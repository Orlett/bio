# %% [markdown]
# <a href="https://colab.research.google.com/github/Orlett/bio/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Домашнее задание N1, Савинов Максим Геннадьевич,2 группа, бактерия Haemophilus ducreyi.

# %% [markdown]
# 1.     Какова длина генома (файл .fna)

# %%
# !wc genom.fna
# Out:
#   20276   20277 1642432 genom.fna

# %% [markdown]
# 1622156
# Удаляем из файла первую строку, и из полученого количества символов вычитаем кол-во строк, так как есть символ переноса строки.

# %% [markdown]
# 2.Сколько генов, кодирующих белки?

# %%
# !grep -c 'protein_coding' feature_table.txt
# Out:
# 1391

# %% [markdown]
# 3.Сколько рнк-генов?

# %%
# !grep -c '^ncRNA' feature_table.txt
# !grep -c '^tRNA' feature_table.txt
# !grep -c '^rRNA' feature_table.txt
# !grep -c '^tmRNA' feature_table.txt
# Out:
# 3
# 49
# 19
# 1

# %% [markdown]
# 72
# Для получения ответа достаточно сложить полученные значения.

# %% [markdown]
# 4.     Сколько транскрипционных факторов?

# %%
# !grep -c 'transcriptional regulator' feature_table.txt
# Out:
# 32

# %% [markdown]
# 5.     Сколько транспортных белков (ABC transporters)?

# %%
# !grep -c 'ABC transporter' feature_table.txt
# Out:
# 55

# %% [markdown]
# 6.   	Сколько tRNA?

# %%
# !grep -c '^tRNA' feature_table.txt
# Out:
# 49

# %% [markdown]
# 7.   	Сколько закодировано субъединиц АTP-synthase?

# %%
# !grep -c 'ATP synthase' feature_table.txt
# Out:
# 9

# %% [markdown]
# 8.     Сколько генов закодировано на положительном, а сколько на отрицательном стренде?

# %%
# !grep '^gene' feature_table.txt| grep -c  '+' 
# !grep '^gene' feature_table.txt| grep -c  '-'
# Out:
# 806
# 753

# %% [markdown]
# Положительных - 806, отрицательных - 753

# %% [markdown]
# Часть 2, Ген HEXA

# %% [markdown]
# 1. В геномном браузере UCSC отобразить все изоформы гена, а также SNPs (common and clinically relevant), участки консервативности среди позвоночных и транспозоны. Сохранить скриншот в виде графического файла.![Снимок экрана (196).png](data:image/png;base64,...)

# %% [markdown]
# Включаем из аннотаций GENECODEv32(pack), RepeatMasker (full), All SNPs(dense), Flagged SNPs(dense) и Conservation (full).

# %% [markdown]
# 2. Отобрать в табличном виде и сохранить в текстовый файл все изоформы генов, попавших в заданный участок.
# Нажимаем на таблицу и получаем файл, он будет в прикрепленном архиве(файл table.txt)![image.png](data:image/png;base64,...)

# %% [markdown]
# 3. Отобрать координаты только экзонов и только интронов для заданного участка.Заходим в table browser,выбираем BED- browser extensible data, и соотвественно выбираем экзоны и интроны, 2 файла будут лежать в архиве(exon.txt,intron.txt)![image.png](data:image/png;base64,...)![image.png](data:image/png;base64,...)

# %% [markdown]
# 4. Ответить письменно, в какие участки гена попадают clinically relevant SNPs.Как видно из скриншота clinically relevant SNPs попадают в экзоны.![Снимок экрана (199).png](data:image/png;base64,...)

# %% [markdown]
# 5.Ответить письменно, в какие участки гена попадают транспозоны. Как видно из скриншота транспозоны попадают в интроны.![Снимок экрана (201).png](data:image/png;base64,...)
